# %% [markdown]
# <a href="https://colab.research.google.com/github/Iprass30/Latihan/blob/main/Data_Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#Membuat Data Frame dari file csv
df = pd.read_csv('https://raw.githubusercontent.com/eliyanto29/My-Academics-Paper-On-Data-Science/master/FCM-Core-and-Reduct/iris_dataset.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv('/content/iris.csv')
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 0             0           5.1          3.5           1.4          0.2        1
# 1             1           4.9          3.0           1.4          0.2        1
# 2             2           4.7          3.2           1.3          0.2        1
# 3             3           4.6          3.1           1.5          0.2        1
# 4             4           5.0          3.6           1.4          0.2        1
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        3
# 146         146           6.3          2.5           5.0          1.9        3
# 147         147           6.5          3.0           5.2          2.0        3
# 148         148           6.2          3.4           5.4          2.3        3
# 149         149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 6 columns]

# %%
#Memanggil data dari urutan atas
df.head(7)
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 0           0           5.1          3.5           1.4          0.2        1
# 1           1           4.9          3.0           1.4          0.2        1
# 2           2           4.7          3.2           1.3          0.2        1
# 3           3           4.6          3.1           1.5          0.2        1
# 4           4           5.0          3.6           1.4          0.2        1
# 5           5           5.4          3.9           1.7          0.4        1
# 6           6           4.6          3.4           1.4          0.3        1

# %%
#Memanggil data dari ututan bawah
df.tail(6)
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 144         144           6.7          3.3           5.7          2.5        3
# 145         145           6.7          3.0           5.2          2.3        3
# 146         146           6.3          2.5           5.0          1.9        3
# 147         147           6.5          3.0           5.2          2.0        3
# 148         148           6.2          3.4           5.4          2.3        3
# 149         149           5.9          3.0           5.1          1.8        3

# %%
#mengetahui informasi dari data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    150 non-null    int64
#  1   sepal_length  150 non-null    float64
#  2   sepal_width   150 non-null    float64
#  3   petal_length  150 non-null    float64
#  4   petal_width   150 non-null    float64
#  5   species       150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
#Data numerik
df.describe()
# Out:
#        Unnamed: 0  sepal_length  ...  petal_width     species
# count  150.000000    150.000000  ...   150.000000  150.000000
# mean    74.500000      5.843333  ...     1.198667    2.000000
# std     43.445368      0.828066  ...     0.763161    0.819232
# min      0.000000      4.300000  ...     0.100000    1.000000
# 25%     37.250000      5.100000  ...     0.300000    1.000000
# 50%     74.500000      5.800000  ...     1.300000    2.000000
# 75%    111.750000      6.400000  ...     1.800000    3.000000
# max    149.000000      7.900000  ...     2.500000    3.000000
#
# [8 rows x 6 columns]

# %%
#Mengambil salah satu kolom dalam data
#Muncul list/array
df['petal_length']
df.petal_width #jika tidak ada spasi
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64

# %%
d1=df[['petal_length','sepal_length']]
d1
# Out:
#      petal_length  sepal_length
# 0             1.4           5.1
# 1             1.4           4.9
# 2             1.3           4.7
# 3             1.5           4.6
# 4             1.4           5.0
# ..            ...           ...
# 145           5.2           6.7
# 146           5.0           6.3
# 147           5.2           6.5
# 148           5.4           6.2
# 149           5.1           5.9
#
# [150 rows x 2 columns]

# %%
#mengakses dari baris tertentu
df2=df[:5]
df2
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 0           0           5.1          3.5           1.4          0.2        1
# 1           1           4.9          3.0           1.4          0.2        1
# 2           2           4.7          3.2           1.3          0.2        1
# 3           3           4.6          3.1           1.5          0.2        1
# 4           4           5.0          3.6           1.4          0.2        1

# %%
#memenggil angka dalam data
df.iloc[:2,:2]
# Out:
#    Unnamed: 0  sepal_length
# 0           0           5.1
# 1           1           4.9

# %%
#Pakai range
df.iloc[2:4, 2:4]
# Out:
#    sepal_width  petal_length
# 2          3.2           1.3
# 3          3.1           1.5

# %%
df.iloc[2::,2::]
# Out:
#      sepal_width  petal_length  petal_width  species
# 2            3.2           1.3          0.2        1
# 3            3.1           1.5          0.2        1
# 4            3.6           1.4          0.2        1
# 5            3.9           1.7          0.4        1
# 6            3.4           1.4          0.3        1
# ..           ...           ...          ...      ...
# 145          3.0           5.2          2.3        3
# 146          2.5           5.0          1.9        3
# 147          3.0           5.2          2.0        3
# 148          3.4           5.4          2.3        3
# 149          3.0           5.1          1.8        3
#
# [148 rows x 4 columns]

# %%
df.iloc[:-100,:-1]
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width
# 0            0           5.1          3.5           1.4          0.2
# 1            1           4.9          3.0           1.4          0.2
# 2            2           4.7          3.2           1.3          0.2
# 3            3           4.6          3.1           1.5          0.2
# 4            4           5.0          3.6           1.4          0.2
# 5            5           5.4          3.9           1.7          0.4
# 6            6           4.6          3.4           1.4          0.3
# 7            7           5.0          3.4           1.5          0.2
# 8            8           4.4          2.9           1.4          0.2
# 9            9           4.9          3.1           1.5          0.1
# 10          10           5.4          3.7           1.5          0.2
# 11          11           4.8          3.4           1.6          0.2
# 12          12           4.8          3.0           1.4          0.1
# ...

# %%
#Eksplorasi datanya apa dan siapa aja
df.count()
# Out:
# Unnamed: 0      150
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.species.count()
# Out:
# 150

# %%
df.species.value_counts()
# Out:
# 3    50
# 2    50
# 1    50
# Name: species, dtype: int64

# %%
#memotong (slice) data frame
df4=df[df['sepal_width']==3.0] #menyatakan kesamaan dengan sepal width sama dengan 3
df4
#jika dengan huruf memakal petik di 3.0
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 1             1           4.9          3.0           1.4          0.2        1
# 12           12           4.8          3.0           1.4          0.1        1
# 13           13           4.3          3.0           1.1          0.1        1
# 25           25           5.0          3.0           1.6          0.2        1
# 38           38           4.4          3.0           1.3          0.2        1
# 45           45           4.8          3.0           1.4          0.3        1
# 61           61           5.9          3.0           4.2          1.5        2
# 66           66           5.6          3.0           4.5          1.5        2
# 75           75           6.6          3.0           4.4          1.4        2
# 77           77           6.7          3.0           5.0          1.7        2
# 84           84           5.4          3.0           4.5          1.5        2
# ...

# %%
df[(df['petal_length']==1.4)& (df['petal_width']==0.1)]
# Out:
#     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  species
# 12          12           4.8          3.0           1.4          0.1        1

# %%
df.petal_length.sum()
# Out:
# 563.8

# %%
dfr = pd.read_csv('/content/Assessment R & Python_ Dataset_superstore_simple.csv')
dfr
# Out:
#             order_id  order_date customer_id  ...     sales quantity    profit
# 0     CA-2016-152156  2016-11-08    CG-12520  ...  261.9600        2   41.9136
# 1     CA-2016-152156  2016-11-08    CG-12520  ...  731.9400        3  219.5820
# 2     CA-2016-138688  2016-06-12    DV-13045  ...   14.6200        2    6.8714
# 3     US-2015-108966  2015-10-11    SO-20335  ...  957.5775        5 -383.0310
# 4     US-2015-108966  2015-10-11    SO-20335  ...   22.3680        2    2.5164
# ...              ...         ...         ...  ...       ...      ...       ...
# 9983  CA-2014-110422  2014-01-21    TB-21400  ...   25.2480        3    4.1028
# 9984  CA-2017-121258  2017-02-26    DB-13060  ...   91.9600        2   15.6332
# 9985  CA-2017-121258  2017-02-26    DB-13060  ...  258.5760        2   19.3932
# 9986  CA-2017-121258  2017-02-26    DB-13060  ...   29.6000        4   13.3200
# 9987  CA-2017-119914  2017-05-04    CC-12220  ...  243.1600        2   72.9480
#
# [9988 rows x 9 columns]

# %%
#1.Tentukan Segment mana dengan profit tertinggi
dfr.segment.value_counts()
# Out:
# Consumer       5188
# Corporate      3019
# Home Office    1781
# Name: segment, dtype: int64

# %%
dfr_Consumer = dfr[dfr['segment']=='Consumer']
dfr_Consumer
# Out:
#             order_id  order_date customer_id  ...     sales quantity    profit
# 0     CA-2016-152156  2016-11-08    CG-12520  ...  261.9600        2   41.9136
# 1     CA-2016-152156  2016-11-08    CG-12520  ...  731.9400        3  219.5820
# 3     US-2015-108966  2015-10-11    SO-20335  ...  957.5775        5 -383.0310
# 4     US-2015-108966  2015-10-11    SO-20335  ...   22.3680        2    2.5164
# 5     CA-2014-115812  2014-06-09    BH-11710  ...   48.8600        7   14.1694
# ...              ...         ...         ...  ...       ...      ...       ...
# 9983  CA-2014-110422  2014-01-21    TB-21400  ...   25.2480        3    4.1028
# 9984  CA-2017-121258  2017-02-26    DB-13060  ...   91.9600        2   15.6332
# 9985  CA-2017-121258  2017-02-26    DB-13060  ...  258.5760        2   19.3932
# 9986  CA-2017-121258  2017-02-26    DB-13060  ...   29.6000        4   13.3200
# 9987  CA-2017-119914  2017-05-04    CC-12220  ...  243.1600        2   72.9480
#
# [5188 rows x 9 columns]

# %%
dfr_Consumer.profit.sum()
# Out:
# 128959.22080000001

# %%
#2. Tentukan category mana dengan sales terbanyak

# %%
#3. Tentukan Sub-category dengan quantity paling sedikit
